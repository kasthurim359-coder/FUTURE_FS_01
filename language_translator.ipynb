# %% [markdown]
# <a href="https://colab.research.google.com/github/kasthurim359-coder/FUTURE_FS_01/blob/main/language_translator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install googletrans==4.0.0-rc1
from googletrans import Translator

translator = Translator()

text = input("Enter text: ")

source_lang = input("Enter source language code (example: en): ")
target_lang = input("Enter target language code (example: ta): ")

translated = translator.translate(
    text,
    src=source_lang,
    dest=target_lang
)

print("\nTranslated Text:")
print(translated.text)
# Out:
# Enter text: good morning
# Enter source language code (example: en): en
# Enter target language code (example: ta): ta
#
# Translated Text:
# காலை வணக்கம்
